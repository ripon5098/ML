# %% [markdown]
# # Visualization1

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.rand(1000), index=pd.date_range('2000-01-01', periods=1000), columns=['Value'])

# %%
df
# Out:
#                Value
# 2000-01-01  0.000328
# 2000-01-02  0.749392
# 2000-01-03  0.926558
# 2000-01-04  0.983682
# 2000-01-05  0.465237
# ...              ...
# 2002-09-22  0.916491
# 2002-09-23  0.061488
# 2002-09-24  0.993919
# 2002-09-25  0.312284
# 2002-09-26  0.574667
#
# [1000 rows x 1 columns]

# %%
#line chart
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.head(30).plot()
# Out:
# <AxesSubplot:>

# %%
df.head(100).plot()
# Out:
# <AxesSubplot:>

# %%
# bar chart
df.head(100).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.head(100).plot(kind='bar', figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
df.head(100).plot(kind='barh', figsize=(20, 10)) #horizontal
# Out:
# <AxesSubplot:>

# %%
df.head(100).plot(kind='hist' , figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head(200).plot(kind='box', figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
df.head(200).plot(kind='kde', figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.head(100).plot()
# Out:
# <AxesSubplot:>

# %%
iris.head(100).plot(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
iris.head(10).plot(kind='bar', figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.loc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.drop('species', axis=1).iloc[3].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.head(10).plot(kind='bar', figsize=(15, 5))
plt.xlabel("Number of flowers")
plt.ylabel("Height of the flowers")
plt.show()

# %%
iris.drop('species', axis=1).iloc[10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[10].plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
# hist plot
iris['sepal_length'].head(40).plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.head(40).plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.hist(figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.hist(color='green', figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.hist(color='red', alpha=0.3,figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# scatter plot
iris.plot.scatter(x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.plot.scatter(x='sepal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.plot.scatter(x='petal_width', y='petal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
iris.plot.scatter(x='petal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
iris.plot.scatter(x='sepal_width', y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %%
iris.plot.scatter(x='petal_width', y='sepal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>

# %%
iris.plot.scatter(x='petal_width', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %%
pd.plotting.scatter_matrix(iris, figsize=(10, 10), color='red')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_width'>]],
#       dtype=object)
